# %%
#importring the libaries
import matplotlib.pyplot as plt

x = [1,2,3,4,3,2,1,5,1,5]
y = [111,112,113,114,113,112,111,115,111,115]

plt.scatter(x,y)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
